# %% [markdown]
# # MNIST 1D Performance
# This notebook aims to run and train a neural network with 2 hidden layers using the MNIST 1D dataset.

# %% [markdown]
# ### Import
# Import the libraries necessary to define all the functions needed to run and train a neural network as well as plot the resulting trained function

# %%
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import numpy as np
import matplotlib.pyplot as plt
import mnist1d

# %% [markdown]
# ### Define Input Data
# Import the MNIST 1D dataset and store the data into variables

# %%
args = mnist1d.data.get_dataset_args()
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=False)
# Out:
# Did or could not load data from ./mnist1d_data.pkl. Rebuilding dataset...

# %% [markdown]
# ### Define Dimensions
# Define the dimensions of the input, hidden, and output layer

# %%
D_i = 40    # Input dimensions
D_k = 100   # Hidden dimensions
D_o = 10    # Output dimensions

# %% [markdown]
# ### Define Neural Network Model
# Define a neural network model with 2 hidden layers, which are defined through the input, hidden, and output layer dimensions

# %%
model = nn.Sequential( 
  nn.Linear(D_i, D_k), 
  nn.ReLU(),
  nn.Linear(D_k, D_k),
  nn.ReLU(), 
  nn.Linear(D_k, D_k),
  nn.ReLU(),
  nn.Linear(D_k, D_o))

# %% [markdown]
# ### Define He Initialization
# Define the He intialization in order to assign variance to the weights of all the layers in the neural network model while keeping the gradients stable to avoid the shrinking or exploding gradient problem

# %%
def weights_init(layer_in):
  if isinstance(layer_in, nn.Linear): 
    nn.init.kaiming_normal_(layer_in.weight)
    layer_in.bias.data.fill_(0.0)
model.apply(weights_init)
# Out:
# Sequential(
#   (0): Linear(in_features=40, out_features=100, bias=True)
#   (1): ReLU()
#   (2): Linear(in_features=100, out_features=100, bias=True)
#   (3): ReLU()
#   (4): Linear(in_features=100, out_features=100, bias=True)
#   (5): ReLU()
#   (6): Linear(in_features=100, out_features=10, bias=True)
# )

# %% [markdown]
# ### Apply He Initialization to Weights

# %%
model.apply(weights_init)
# Out:
# Sequential(
#   (0): Linear(in_features=40, out_features=100, bias=True)
#   (1): ReLU()
#   (2): Linear(in_features=100, out_features=100, bias=True)
#   (3): ReLU()
#   (4): Linear(in_features=100, out_features=100, bias=True)
#   (5): ReLU()
#   (6): Linear(in_features=100, out_features=10, bias=True)
# )

# %% [markdown]
# ### Define Loss Function
# Define the cross entropy loss function as the loss function for this neural network

# %%
loss_function = torch.nn.CrossEntropyLoss()

# %% [markdown]
# ### Define the Stochastic Gradient Descent Function
# Define the stochastic gradient descent function by initializing its momentum and learning rate

# %%
optimizer = torch.optim.SGD(model.parameters(), lr = 0.05, momentum=0.9)

# %% [markdown]
# ### Define Scheduler
# Define a variable (scheduler) that decreases the learning rate by half for every 10 epochs (entire pass through entire dataset)

# %%
scheduler = StepLR(optimizer, step_size=10, gamma=0.5)
x_train = torch.tensor(data['x'].astype('float32'))
y_train = torch.tensor(data['y'].transpose().astype('int64'))
x_test= torch.tensor(data['x_test'].astype('float32'))
y_test = torch.tensor(data['y_test'].astype('int64'))

# %% [markdown]
# ### Define Batch
# Define a variable (data_loader) to store randomly defined batches of data for the stochastic gradient descent function

# %%
data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

# %% [markdown]
# ### Initialize Weights
# Initialize the value of the weights by using the He initialization function

# %%
model.apply(weights_init)
# Out:
# Sequential(
#   (0): Linear(in_features=40, out_features=100, bias=True)
#   (1): ReLU()
#   (2): Linear(in_features=100, out_features=100, bias=True)
#   (3): ReLU()
#   (4): Linear(in_features=100, out_features=100, bias=True)
#   (5): ReLU()
#   (6): Linear(in_features=100, out_features=10, bias=True)
# )

# %% [markdown]
# ### Define Epochs
# Define the number of epochs (entire pass through entire dataset) to run the neural network model over

# %%
n_epoch = 50

# %% [markdown]
# ### Define Loss Array Structures
# Define the array structure for the loss and the % correct for each epoch for both the training and the test set

# %%
losses_train = np.zeros((n_epoch))
errors_train = np.zeros((n_epoch))
losses_test = np.zeros((n_epoch))
errors_test = np.zeros((n_epoch))

# %% [markdown]
# ### Optimize Loss of Neural Network
# Optimize the loss of the neural network model by computing the forward and backward pass for each batch of data (back propagation) and updating the value of the parameters using the stochastic gradient descent. Compute the % accurate and loss for both the training and test set for each epoch.

# %%
# Optimize the neural network over each epoch
for epoch in range(n_epoch):
  # For each batch of data
  for i, batch in enumerate(data_loader):
    # Retrieve inputs and labels for this batch
    x_batch, y_batch = batch
    # Zero the parameter gradients
    optimizer.zero_grad()
    # Compute the forward pass, return the model's output
    pred = model(x_batch)
    # Compute the loss
    loss = loss_function(pred, y_batch)
    # Compute the backward pass
    loss.backward()
    # Update the position using stocahstic gradient descent (SGD)
    optimizer.step()

  # Compute the statistics by running the whole dataset
  pred_train = model(x_train)
  pred_test = model(x_test)
  _, predicted_train_class = torch.max(pred_train.data, 1)
  _, predicted_test_class = torch.max(pred_test.data, 1)
  errors_train[epoch] = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
  errors_test[epoch]= 100 - 100 * (predicted_test_class == y_test).float().sum() / len(y_test)
  losses_train[epoch] = loss_function(pred_train, y_train).item()
  losses_test[epoch]= loss_function(pred_test, y_test).item()
  print(f'Epoch {epoch:5d}, train loss {losses_train[epoch]:.6f}, train error {errors_train[epoch]:3.2f},  test loss {losses_test[epoch]:.6f}, test error {errors_test[epoch]:3.2f}')

  # Track when to update learning rate through scheduler
  scheduler.step()
# Out:
# Epoch     0, train loss 1.566405, train error 63.15,  test loss 1.655140, test error 66.10
# Epoch     1, train loss 1.253681, train error 46.10,  test loss 1.443806, test error 55.80
# Epoch     2, train loss 1.087158, train error 39.88,  test loss 1.365539, test error 54.10
# Epoch     3, train loss 0.964737, train error 34.70,  test loss 1.316721, test error 51.00
# Epoch     4, train loss 0.879371, train error 32.12,  test loss 1.235337, test error 48.80
# Epoch     5, train loss 0.721282, train error 24.82,  test loss 1.213032, test error 47.50
# Epoch     6, train loss 0.599293, train error 20.62,  test loss 1.127798, test error 41.40
# Epoch     7, train loss 0.565255, train error 20.15,  test loss 1.193250, test error 43.90
# Epoch     8, train loss 0.507651, train error 18.10,  test loss 1.213124, test error 41.70
# Epoch     9, train loss 0.428990, train error 15.15,  test loss 1.212392, test error 40.50
# Epoch    10, train loss 0.245107, train error 6.35,  test loss 1.077686, test error 37.60
# Epoch    11, train loss 0.202334, train error 4.72,  test loss 1.148675, test error 37.40
# Epoch    12, train loss 0.173492, train error 3.85,  test loss 1.173485, test error 37.00
# Epoch    13, train loss 0.123921, train error 1.72,  test loss 1.157917, test error 36.10
# Epoch    14, train loss 0.104412, train error 1.07,  test loss 1.233805, test error 37.60
# Epoch    15, train loss 0.085401, train error 0.82,  test loss 1.268063, test error 36.20
# Epoch    16, train loss 0.071548, train error 0.47,  test loss 1.284150, test error 35.30
# Epoch    17, train loss 0.060580, train error 0.25,  test loss 1.385472, test error 36.60
# Epoch    18, train loss 0.046155, train error 0.15,  test loss 1.379151, test error 36.50
# Epoch    19, train loss 0.037353, train error 0.10,  test loss 1.410682, test error 36.60
# Epoch    20, train loss 0.030658, train error 0.07,  test loss 1.423088, test error 35.70
# Epoch    21, train loss 0.027984, train error 0.05,  test loss 1.436808, test error 35.90
# Epoch    22, train loss 0.025859, train error 0.00,  test loss 1.451300, test error 36.40
# Epoch    23, train loss 0.023907, train error 0.00,  test loss 1.471746, test error 35.80
# Epoch    24, train loss 0.022207, train error 0.00,  test loss 1.491084, test error 35.50
# Epoch    25, train loss 0.021227, train error 0.00,  test loss 1.504642, test error 35.80
# Epoch    26, train loss 0.019746, train error 0.00,  test loss 1.511995, test error 35.50
# Epoch    27, train loss 0.018635, train error 0.00,  test loss 1.531468, test error 35.90
# Epoch    28, train loss 0.017680, train error 0.00,  test loss 1.537390, test error 35.70
# Epoch    29, train loss 0.016812, train error 0.00,  test loss 1.548270, test error 35.30
# Epoch    30, train loss 0.016117, train error 0.00,  test loss 1.557374, test error 35.10
# Epoch    31, train loss 0.015716, train error 0.00,  test loss 1.561409, test error 35.30
# Epoch    32, train loss 0.015347, train error 0.00,  test loss 1.568387, test error 35.30
# Epoch    33, train loss 0.014945, train error 0.00,  test loss 1.575003, test error 35.20
# Epoch    34, train loss 0.014607, train error 0.00,  test loss 1.582524, test error 35.20
# Epoch    35, train loss 0.014281, train error 0.00,  test loss 1.587792, test error 35.10
# Epoch    36, train loss 0.013944, train error 0.00,  test loss 1.590880, test error 35.40
# Epoch    37, train loss 0.013643, train error 0.00,  test loss 1.598942, test error 35.50
# Epoch    38, train loss 0.013355, train error 0.00,  test loss 1.599941, test error 35.10
# Epoch    39, train loss 0.013109, train error 0.00,  test loss 1.608172, test error 35.30
# Epoch    40, train loss 0.012917, train error 0.00,  test loss 1.608988, test error 35.10
# Epoch    41, train loss 0.012778, train error 0.00,  test loss 1.611944, test error 35.20
# Epoch    42, train loss 0.012656, train error 0.00,  test loss 1.614983, test error 35.30
# Epoch    43, train loss 0.012527, train error 0.00,  test loss 1.617364, test error 35.10
# Epoch    44, train loss 0.012400, train error 0.00,  test loss 1.618610, test error 35.40
# Epoch    45, train loss 0.012267, train error 0.00,  test loss 1.622330, test error 35.20
# Epoch    46, train loss 0.012148, train error 0.00,  test loss 1.623713, test error 35.10
# Epoch    47, train loss 0.012028, train error 0.00,  test loss 1.627073, test error 35.20
# Epoch    48, train loss 0.011916, train error 0.00,  test loss 1.630076, test error 35.30
# Epoch    49, train loss 0.011803, train error 0.00,  test loss 1.630717, test error 35.20

# %% [markdown]
# ### Plot the Results (% correct)

# %%
fig, ax = plt.subplots()
ax.plot(errors_train,'r-',label='train')
ax.plot(errors_test,'b-',label='test')
ax.set_ylim(0,100); ax.set_xlim(0,n_epoch)
ax.set_xlabel('Epoch'); ax.set_ylabel('Error')
ax.set_title('TrainError %3.2f, Test Error %3.2f'%(errors_train[-1],errors_test[-1]))
ax.legend()
plt.show()

# %% [markdown]
# ### Plot the Results (Loss)

# %%
fig, ax = plt.subplots()
ax.plot(losses_train,'r-',label='train')
ax.plot(losses_test,'b-',label='test')
ax.set_xlim(0,n_epoch)
ax.set_xlabel('Epoch'); ax.set_ylabel('Loss')
ax.set_title('Train loss %3.2f, Test loss %3.2f'%(losses_train[-1],losses_test[-1]))
ax.legend()
plt.show()
